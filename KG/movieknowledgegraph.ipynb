# %%
from dotenv import load_dotenv
import os
from langchain_community.graphs import Neo4jGraph

load_dotenv('.env.studiomac',override=True)
NEO4J_URI = os.getenv("NEO4J_URI")
NEO4J_USERNAME = os.getenv("NEO4J_USERNAME")
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD")
NEO4J_DATABASE = os.getenv("NEO4J_DATABASE")

kg = Neo4jGraph(
    url=NEO4J_URI,
    username=NEO4J_USERNAME,
    password=NEO4J_PASSWORD,
    database=NEO4J_DATABASE,
)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File ~/Desktop/code/learn/KG/.venv/lib/python3.9/site-packages/langchain_community/graphs/neo4j_graph.py:429, in Neo4jGraph.__init__(self, url, username, password, database, timeout, sanitize, refresh_schema, driver_config, enhanced_schema)
#     428 try:
# --> 429     self.refresh_schema()
#     430 except neo4j.exceptions.ClientError as e:
#
# File ~/Desktop/code/learn/KG/.venv/lib/python3.9/site-packages/langchain_community/graphs/neo4j_graph.py:511, in Neo4jGraph.refresh_schema(self)
#     507 from neo4j.exceptions import ClientError, CypherTypeError
#     509 node_properties = [
#     510     el["output"]
# --> 511     for el in self.query(
#     512         node_properties_query,
#     513         params={"EXCLUDED_LABELS": EXCLUDED_LABELS + [BASE_ENTITY_LABEL]},
#     514     )
#     515 ]
#     516 rel_properties = [
#     517     el["output"]
#     518     for el in self.query(
#     519         rel_properties_query, params={"EXCLUDED_LABELS": EXCLUDED_RELS}
#     520     )
#     521 ]
#
# File ~/Desktop/code/learn/KG/.venv/lib/python3.9/site-packages/langchain_community/graphs/neo4j_graph.py:467, in Neo4jGraph.query(self, query, params)
#     466 try:
# --> 467     data, _, _ = self._driver.execute_query(
#     468         Query(text=query, timeout=self.timeout),
#     469         database_=self._database,
#     470         parameters_=params,
#     471     )
#     472     json_data = [r.data() for r in data]
#
# File ~/Desktop/code/learn/KG/.venv/lib/python3.9/site-packages/neo4j/_sync/driver.py:970, in Driver.execute_query(self, query_, parameters_, routing_, database_, impersonated_user_, bookmark_manager_, auth_, result_transformer_, **kwargs)
#     969 with session._pipelined_begin:
# --> 970     return session._run_transaction(
#     971         access_mode,
#     972         TelemetryAPI.DRIVER,
#     973         work,
#     974         (query_str, parameters, result_transformer_),
#     975         {},
#     976     )
#
# File ~/Desktop/code/learn/KG/.venv/lib/python3.9/site-packages/neo4j/_sync/work/session.py:583, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#     582 try:
# --> 583     result = transaction_function(tx, *args, **kwargs)
#     584 except asyncio.CancelledError:
#     585     # if cancellation callback has not been called yet:
#
# File ~/Desktop/code/learn/KG/.venv/lib/python3.9/site-packages/neo4j/_work/query.py:144, in unit_of_work.<locals>.wrapper.<locals>.wrapped(*args, **kwargs)
#     143 def wrapped(*args, **kwargs):
# --> 144     return f(*args, **kwargs)
#
# File ~/Desktop/code/learn/KG/.venv/lib/python3.9/site-packages/neo4j/_sync/driver.py:1306, in _work(tx, query, parameters, transformer)
#    1300 def _work(
#    1301     tx: ManagedTransaction,
#    1302     query: te.LiteralString,
#    1303     parameters: dict[str, t.Any],
#    1304     transformer: t.Callable[[Result], t.Union[_T]],
#    1305 ) -> _T:
# -> 1306     res = tx.run(query, parameters)
#    1307     return transformer(res)
#
# File ~/Desktop/code/learn/KG/.venv/lib/python3.9/site-packages/neo4j/_sync/work/transaction.py:206, in TransactionBase.run(self, query, parameters, **kwparameters)
#     205 parameters = dict(parameters or {}, **kwparameters)
# --> 206 result._tx_ready_run(query, parameters)
#     208 return result
#
# File ~/Desktop/code/learn/KG/.venv/lib/python3.9/site-packages/neo4j/_sync/work/result.py:177, in Result._tx_ready_run(self, query, parameters)
#     173 def _tx_ready_run(self, query, parameters):
#     174     # BEGIN+RUN does not carry any extra on the RUN message.
#     175     # BEGIN {extra}
#     176     # RUN "query" {parameters} {extra}
# --> 177     self._run(query, parameters, None, None, None, None, None, None)
#
# File ~/Desktop/code/learn/KG/.venv/lib/python3.9/site-packages/neo4j/_sync/work/result.py:236, in Result._run(self, query, parameters, db, imp_user, access_mode, bookmarks, notifications_min_severity, notifications_disabled_classifications)
#     235 self._connection.send_all()
# --> 236 self._attach()
#
# File ~/Desktop/code/learn/KG/.venv/lib/python3.9/site-packages/neo4j/_sync/work/result.py:430, in Result._attach(self)
#     429 while self._attached is False:
# --> 430     self._connection.fetch_message()
#
# File ~/Desktop/code/learn/KG/.venv/lib/python3.9/site-packages/neo4j/_sync/io/_common.py:184, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#     183 try:
# --> 184     func(*args, **kwargs)
#     185 except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#
# File ~/Desktop/code/learn/KG/.venv/lib/python3.9/site-packages/neo4j/_sync/io/_bolt.py:864, in Bolt.fetch_message(self)
#     861 tag, fields = self.inbox.pop(
#     862     hydration_hooks=self.responses[0].hydration_hooks
#     863 )
# --> 864 res = self._process_message(tag, fields)
#     865 self.idle_since = monotonic()
#
# File ~/Desktop/code/learn/KG/.venv/lib/python3.9/site-packages/neo4j/_sync/io/_bolt4.py:498, in Bolt4x0._process_message(self, tag, fields)
#     497 try:
# --> 498     response.on_failure(summary_metadata or {})
#     499 except (ServiceUnavailable, DatabaseUnavailable):
#
# File ~/Desktop/code/learn/KG/.venv/lib/python3.9/site-packages/neo4j/_sync/io/_common.py:254, in Response.on_failure(self, metadata)
#     253 Util.callback(handler)
# --> 254 raise self._hydrate_error(metadata)
#
# ClientError: {code: Neo.ClientError.Procedure.ProcedureNotFound} {message: There is no procedure with the name `apoc.meta.data` registered for this database instance. Please ensure you've spelled the procedure name correctly and that the procedure is properly deployed.}
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 11
#       8 NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD")
#       9 NEO4J_DATABASE = os.getenv("NEO4J_DATABASE")
# ---> 11 kg = Neo4jGraph(
#      12     url=NEO4J_URI,
#      13     username=NEO4J_USERNAME,
#      14     password=NEO4J_PASSWORD,
#      15     database=NEO4J_DATABASE,
#      16 )
#
# File ~/Desktop/code/learn/KG/.venv/lib/python3.9/site-packages/langchain_core/_api/deprecation.py:222, in deprecated.<locals>.deprecate.<locals>.finalize.<locals>.warn_if_direct_instance(self, *args, **kwargs)
#     220     warned = True
#     221     emit_warning()
# --> 222 return wrapped(self, *args, **kwargs)
#
# File ~/Desktop/code/learn/KG/.venv/lib/python3.9/site-packages/langchain_community/graphs/neo4j_graph.py:432, in Neo4jGraph.__init__(self, url, username, password, database, timeout, sanitize, refresh_schema, driver_config, enhanced_schema)
#     430 except neo4j.exceptions.ClientError as e:
#     431     if e.code == "Neo.ClientError.Procedure.ProcedureNotFound":
# --> 432         raise ValueError(
#     433             "Could not use APOC procedures. "
#     434             "Please ensure the APOC plugin is installed in Neo4j and that "
#     435             "'apoc.meta.data()' is allowed in Neo4j configuration "
#     436         )
#     437     raise e
#
# ValueError: Could not use APOC procedures. Please ensure the APOC plugin is installed in Neo4j and that 'apoc.meta.data()' is allowed in Neo4j configuration
